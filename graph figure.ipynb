# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
ax1.scatter(np.arange(30), np.arange(30)+np.random.randn(30))

# %%
plt.figure()
