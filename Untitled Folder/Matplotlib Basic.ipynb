# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Example 1
plt.plot(np.arange(10))

# %%
plt.show()

# %%
#Example 2
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %%
#Example 3
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.show()

# %%
#Example 4
plt.plot([1,2,3,4],[1,4,9,16],'r-')
plt.show()

# %%
#Example 5 multiple arrays in a graph
t = np.arange(0., 5., 0.2)

plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
