# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#         Rank     Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago    Bears     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  England  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division
# 1    NFC    North
# 2   East     None
# 3  North     None
# 4  North     None
# 5    AFC     East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First', 'NFL',
#        'season', 'Division'],
#       dtype='object')

# %%
nfl_frame.Rank
# Out:
# 1        Green
# 2       Dallas
# 3    Baltimore
# 4      Chicago
# 5          New
# Name: Rank, dtype: object

# %%
DataFrame(nfl_frame,columns=['Team','First'])
# Out:
#       Team     First
# 1      Bay     0.569
# 2  Cowboys  1960.000
# 3   Ravens  1996.000
# 4    Bears  1920.000
# 5  England     0.562

# %%
nfl_frame
# Out:
#         Rank     Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago    Bears     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  England  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division
# 1    NFC    North
# 2   East     None
# 3  North     None
# 4  North     None
# 5    AFC     East

# %%
nfl_frame.head(2)
# Out:
#      Rank     Team       GP    Won  Lost  Tied    Pct.     First   NFL season  \
# 1   Green      Bay  Packers  1,384   769   577  38.000     0.569  1921    NFC
# 2  Dallas  Cowboys      930    526   398     6   0.569  1960.000   NFC   East
#
#   Division
# 1    North
# 2     None

# %%
nfl_frame.tail(2)
# Out:
#       Rank     Team        GP  Won  Lost  Tied   Pct.     First   NFL season  \
# 4  Chicago    Bears     1,418  777   599    42  0.563  1920.000   NFC  North
# 5      New  England  Patriots  932   519   404  9.000     0.562  1960    AFC
#
#   Division
# 4     None
# 5     East

# %%
nfl_frame.ix[3]
# Out:
# C:\Users\khj01\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Rank        Baltimore
# Team           Ravens
# GP                400
# Won               225
# Lost              174
# Tied                1
# Pct.            0.564
# First            1996
# NFL               AFC
# season          North
# Division         None
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#         Rank     Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago    Bears     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  England  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division         Stadium
# 1    NFC    North  Levi's Stadium
# 2   East     None  Levi's Stadium
# 3  North     None  Levi's Stadium
# 4  North     None  Levi's Stadium
# 5    AFC     East  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#         Rank     Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago    Bears     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  England  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division  Stadium
# 1    NFC    North        0
# 2   East     None        1
# 3  North     None        2
# 4  North     None        3
# 5    AFC     East        4

# %%
stadiums = Series(["Levi's Stadium","AT&TR Stadium"],index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0     AT&TR Stadium
# dtype: object

# %%
nfl_frame
# Out:
#         Rank     Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago    Bears     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  England  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division  Stadium
# 1    NFC    North        0
# 2   East     None        1
# 3  North     None        2
# 4  North     None        3
# 5    AFC     East        4

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#         Rank     Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago    Bears     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  England  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division         Stadium
# 1    NFC    North             NaN
# 2   East     None             NaN
# 3  North     None             NaN
# 4  North     None  Levi's Stadium
# 5    AFC     East             NaN

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#         Rank     Team        GP    Won  Lost  Tied    Pct.     First   NFL  \
# 1      Green      Bay   Packers  1,384   769   577  38.000     0.569  1921
# 2     Dallas  Cowboys       930    526   398     6   0.569  1960.000   NFC
# 3  Baltimore   Ravens       400    225   174     1   0.564  1996.000   AFC
# 4    Chicago    Bears     1,418    777   599    42   0.563  1920.000   NFC
# 5        New  England  Patriots    932   519   404   9.000     0.562  1960
#
#   season Division
# 1    NFC    North
# 2   East     None
# 3  North     None
# 4  North     None
# 5    AFC     East

# %%
data = {'City':['SF','LA'],'Population':[80000,70000]}

# %%
city = DataFrame(data)

# %%
city
# Out:
#   City  Population
# 0   SF       80000
# 1   LA       70000
