# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# ax.plot(x,y,'g--')
# ax.plot(x,y, linestyle='--', color='g')
from numpy.random import randn
data = randn(30).cumsum()

# %%
plt.plot(data,'ko--')
#including marker

# %%
plt.plot(data,color='k',linestyle='dashed',marker='o')

# %%
plt.plot(data,color='C0',linestyle='solid',label='solid')

# %%
plt.plot(data,color='k',linestyle='dotted',label='dotted')

# %%
plt.plot(data,color='k',linestyle='dashed',label='dashed')

# %%
plt.plot(data,color='k',linestyle='dashdot',label='Dash-dot')
